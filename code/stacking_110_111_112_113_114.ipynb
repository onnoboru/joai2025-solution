# %%
from sklearn.metrics import f1_score
import numpy as np

def lgb_f1_score_weighted(preds, data):
    y_true = data.get_label()
    # LightGBM では preds は [num_class * num_samples] の形で渡ってくる
    y_pred = preds.reshape(len(np.unique(y_true)), -1).argmax(axis=0)
    score = f1_score(y_true, y_pred, average='weighted')
    return 'f1_weighted', score, True

# %%
import pandas as pd
import os
import lightgbm

# 実験リスト
exp_list = [
    # "010_film", 
    # "016_film_roberta",
    # "017_film_mean_pool",
    # "018_film_gem",
    # "019_film_gem_gray",
    # "020_film_four_channel",
    # "021_film_four_channel_1out",
    # "022_one_out_100epoch_fixed",
    # "023_film_four_channel_one_out_roberta_fixed",
    # "a01_gem_deberta_anotherseed",
    # "a02_gem_roberta_anotherseed",
    # "a03_film_anotherseed",
    # "a04_multiclass_gem_anotherseed",
    # "024_pooling_none_fixed", 
    "110_film",
    "111_gem",
    "112_oneout_base",
    "113_oneout_roberta",
    "114_oneout_default_pooling",
]

# 基本カラムとターゲットカラム
base_cols = ["MQ8", "MQ5", "min_temp", "max_temp", "dff_tmp", "fold"]
target_cols = ['Mixture', 'NoGas', 'Perfume', 'Smoke']

# 結合するカラムを定義
columns_list = base_cols.copy()
for exp in exp_list:
    for col in target_cols:
        columns_list.append(f"{exp}_{col}")

# クロスバリデーション結果と予測結果を取得
oof_df_path_list = [os.path.join("../outputs", f'{exp}_oof.csv') for exp in exp_list]
test_df_path_list = [os.path.join("../outputs", f'{exp}_test_probs.csv') for exp in exp_list]

# CSVをデータフレームに読み込み
oof_df_list = [pd.read_csv(path) for path in oof_df_path_list]
test_df_list = [pd.read_csv(path) for path in test_df_path_list]

def get_oof_df(df_list, is_train=True):
    """異なるモデルの出力を結合したデータフレームを作成"""
    # 行数を取得
    nrows = len(df_list[0])
    
    # 結合用の空のデータフレームを作成
    result_df = pd.DataFrame(index=range(nrows))
    
    # 基本列のコピー (訓練データから)
    for col in base_cols:
        if col in df_list[0].columns:
            result_df[col] = df_list[0][col].values
    
    # 訓練データにはGas列が含まれる場合がある
    if is_train and "Gas" in df_list[0].columns:
        result_df["Gas"] = df_list[0]["Gas"].values
    
    # 各モデルの予測確率を追加
    for i, exp in enumerate(exp_list):
        for col in target_cols:
            if col in df_list[i].columns:
                result_df[f"{exp}_{col}"] = df_list[i][col].values
    
    return result_df

# 訓練データと予測データを構築
oof_df_train = get_oof_df(oof_df_list, is_train=True)
oof_df_test = get_oof_df(test_df_list, is_train=False)

oof_df_train["another_fold"] = pd.read_csv("../dataset/train_folds_another_seed.csv")["fold"]

display(oof_df_train.head())
display(oof_df_test.head())

test_preds = []
oof_df_train["Mixture"] = 0
oof_df_train["NoGas"] = 0
oof_df_train["Perfume"] = 0
oof_df_train["Smoke"] = 0

fold_list = ["fold", "another_fold"]
# 訓練データと検証データの準備
for fold in fold_list:
    df_X = oof_df_train.drop(columns=["Gas"])
    df_y = oof_df_train["Gas"]
    
    # 検証用の分割
    fold_results = []
    for i in range(5):
        train_X = df_X[df_X[fold] != i].drop(columns=["fold","another_fold", "Mixture", "NoGas", "Perfume", "Smoke"])
        train_y = df_y[df_X[fold] != i]
        valid_X = df_X[df_X[fold] == i].drop(columns=["fold","another_fold", "Mixture", "NoGas", "Perfume", "Smoke"])
        valid_y = df_y[df_X[fold] == i]
        valid_index = df_X[df_X[fold] == i].index
        display(train_y.head())
        
        def transform(df):
            for target_col in target_cols:
                df[f"diff_max_{target_col}_MQ5"] = train_X[train_y == target_col]["MQ5"].max() - df["MQ5"]
                df[f"diff_max_{target_col}_MQ8"] = train_X[train_y == target_col]["MQ8"].max() - df["MQ8"]
                df[f"diff_min_{target_col}_MQ5"] = train_X[train_y == target_col]["MQ5"].max() - df["MQ5"]
                df[f"diff_min_{target_col}_MQ8"] = train_X[train_y == target_col]["MQ8"].max() - df["MQ8"]
                
            return df
        
        train_X = transform(train_X)
        valid_X = transform(valid_X)
        
        # ここで学習・予測処理を行う
        # モデル学習のコード...
        
        # テストデータの準備
        test_X = oof_df_test.copy()
        if "fold" in test_X.columns:
            test_X = test_X.drop(columns=["fold"])

        if "another_fold" in test_X.columns:
            test_X = test_X.drop(columns=["another_fold"])
        
        name_to_label = {
                    "Mixture": 0,
                    "NoGas": 1,
                    "Perfume": 2,
                    "Smoke": 3
        }
        train_y = train_y.map(name_to_label)
        valid_y = valid_y.map(name_to_label)

        lgbm_params = {
            "objective": "multiclass",
            "num_class": 4,
            "boosting_type": "gbdt",
            "learning_rate": 0.01,
            "max_depth": 5,
            "num_leaves": 16,
            "bagging_fraction": 0.2,
            "feature_fraction": 0.2,
            "bagging_seed": 42,
            "seed": 42 if fold == "fold" else 496,
            "verbosity": -1,
            "num_threads": 4,
        }
        # モデル学習のコード...
        print("A")
        model = lightgbm.train(
            params=lgbm_params,
            train_set=lightgbm.Dataset(train_X, label=train_y),
            valid_sets=[lightgbm.Dataset(valid_X, label=valid_y)],
            num_boost_round=20000,
            callbacks=[lightgbm.log_evaluation(100), lightgbm.early_stopping(200)],
        )
        test_X = transform(test_X)
        preds = model.predict(test_X)
        preds_df = pd.DataFrame(preds, columns=["Mixture", "NoGas", "Perfume", "Smoke"])
        test_preds.append(preds)
        preds = model.predict(valid_X)
        # Get feature importances
        if i == 0:
            importance = model.feature_importance(importance_type="gain")
            # Create a DataFrame with feature names and importance values
            feature_importance_df = pd.DataFrame({
                'Feature': valid_X.columns,
                'Importance': importance
            }).sort_values(by='Importance', ascending=False)
            # Display top features
            print("Top 30 important features:")
            display(feature_importance_df.head(30))
            # Optionally plot feature importances
            import matplotlib.pyplot as plt
            plt.figure(figsize=(10, 8))
            plt.barh(feature_importance_df['Feature'][:30], feature_importance_df['Importance'][:30])
            plt.xlabel('Importance')
            plt.title('Feature Importance (Gain)')
            plt.gca().invert_yaxis()  # Display most important feature at the top
            plt.tight_layout()
            plt.show()
        # oof_df_train の該当行に予測結果を保存
        for j, col in enumerate(target_cols):
            oof_df_train.loc[valid_index, col] += preds[:, j] / len(fold_list)
            
    
test_preds = np.mean(test_preds, axis=0)
preds_df = pd.DataFrame(test_preds, columns=["Mixture", "NoGas", "Perfume", "Smoke"])

display(preds_df)
display(oof_df_train)
y_true_numeric = oof_df_train["Gas"].map(name_to_label)
y_pred_labels = oof_df_train[target_cols].idxmax(axis=1)
y_pred_numeric = y_pred_labels.map(name_to_label)
print(f"OOF F1スコア: {f1_score(y_true_numeric, y_pred_numeric, average='weighted')}")
# 出力ファイル名の設定
out_str = "_".join([exp[:3] for exp in exp_list])
sub = pd.read_csv("../dataset/sample_submission.csv")
sub["Gas"] = preds_df.idxmax(axis=1)
# Out:
#    MQ8  MQ5   min_temp   max_temp    dff_tmp  fold      Gas  110_film_Mixture  \
# 0  632  418  28.000000  31.000000   3.000000     0    NoGas          0.000000
# 1  567  392  30.000000  30.000000   0.000000     2  Perfume          0.000000
# 2  562  393  31.111111  31.111111   0.000000     4  Perfume          0.032340
# 3  352  441  21.666667  22.222222   0.555556     3  Mixture          0.957907
# 4  603  412  17.000000  36.000000  19.000000     4  Perfume          0.000000
#
#    110_film_NoGas  110_film_Perfume  ...  112_oneout_base_Smoke  \
# 0        0.964642          0.010194  ...               0.000000
# 1        0.105679          0.863205  ...               0.000000
# 2        0.243037          0.687438  ...               0.104309
# 3        0.014041          0.013309  ...               0.058845
# 4        0.016182          0.956950  ...               0.000000
#
#    113_oneout_roberta_Mixture  113_oneout_roberta_NoGas  \
# 0                    0.000000                  0.926514
# 1                    0.000000                  0.272972
# 2                    0.072872                  0.494995
# 3                    0.945557                  0.058624
# 4                    0.000000                  0.120871
#
#    113_oneout_roberta_Perfume  113_oneout_roberta_Smoke  \
# 0                    0.051624                  0.000000
# 1                    0.742676                  0.000000
# 2                    0.905518                  0.043392
# 3                    0.055412                  0.053555
# 4                    0.838623                  0.000000
#
#    114_oneout_default_pooling_Mixture  114_oneout_default_pooling_NoGas  \
# 0                            0.000000                          2.938232
# 1                            0.000000                          0.626892
# 2                            0.114975                          0.270081
# 3                            2.941895                          0.067022
# 4                            0.000000                          0.129822
#
#    114_oneout_default_pooling_Perfume  114_oneout_default_pooling_Smoke  \
# 0                            0.075432                          0.000000
# 1                            1.818848                          0.000000
# 2                            1.781982                          0.046670
# 3                            0.077293                          0.070049
# 4                            2.956299                          0.000000
#
#    another_fold
# 0             0
# 1             2
# 2             4
# 3             3
# 4             4
#
# [5 rows x 28 columns]
#    MQ8  MQ5   min_temp   max_temp    dff_tmp  110_film_Mixture  \
# 0  621  345  36.666667  41.111111   4.444444          0.014915
# 1  718  457  34.000000  34.000000   0.000000          0.000000
# 2  640  414  30.555556  31.111111   0.555556          0.016241
# 3  710  485  29.000000  29.000000   0.000000          0.000000
# 4  361  438   5.000000  22.222222  17.222222          0.957764
#
#    110_film_NoGas  110_film_Perfume  110_film_Smoke  111_gem_Mixture  ...  \
# 0        0.014527          0.013527        0.957031         0.003069  ...
# 1        0.037322          0.932598        0.000000         0.000000  ...
# 2        0.946284          0.017016        0.020459         0.002724  ...
# 3        0.936733          0.031271        0.000000         0.000000  ...
# 4        0.013634          0.014297        0.014305         0.991953  ...
#
#    112_oneout_base_Perfume  112_oneout_base_Smoke  113_oneout_roberta_Mixture  \
# 0                 0.055092               0.949304                    0.042937
# 1                 0.910718               0.000000                    0.000000
# 2                 0.053975               0.090370                    0.064548
# 3                 0.070366               0.000000                    0.000000
# 4                 0.055676               0.056622                    0.944885
#
#    113_oneout_roberta_NoGas  113_oneout_roberta_Perfume  \
# 0                  0.050896                    0.050192
# 1                  0.086519                    0.934351
# 2                  0.952051                    0.055012
# 3                  0.929614                    0.076765
# 4                  0.058356                    0.053541
#
#    113_oneout_roberta_Smoke  114_oneout_default_pooling_Mixture  \
# 0                  0.948987                            0.067578
# 1                  0.000000                            0.000000
# 2                  0.065362                            0.086742
# 3                  0.000000                            0.000000
# 4                  0.059236                            2.936218
#
#    114_oneout_default_pooling_NoGas  114_oneout_default_pooling_Perfume  \
# 0                          0.069325                            0.079340
# 1                          0.233291                            2.808350
# 2                          2.931335                            0.076521
# 3                          2.892822                            0.115852
# 4                          0.070498                            0.071775
#
#    114_oneout_default_pooling_Smoke
# 0                          2.920471
# 1                          0.000000
# 2                          0.253830
# 3                          0.000000
# 4                          0.083553
#
# [5 rows x 25 columns]
# 1    Perfume
# 2    Perfume
# 3    Mixture
# 4    Perfume
# 6    Mixture
# Name: Gas, dtype: object
# A
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's multi_logloss: 0.278575
# [200]	valid_0's multi_logloss: 0.0827126
# [300]	valid_0's multi_logloss: 0.0384056
# [400]	valid_0's multi_logloss: 0.0280618
# [500]	valid_0's multi_logloss: 0.0251548
# [600]	valid_0's multi_logloss: 0.0243803
# [700]	valid_0's multi_logloss: 0.0249195
# Early stopping, best iteration is:
# [599]	valid_0's multi_logloss: 0.0243559
# Top 30 important features:
#                                Feature    Importance
# 13             112_oneout_base_Mixture  52744.131038
# 7                     110_film_Perfume  41907.429088
# 1                                  MQ5  38314.485212
# 15             112_oneout_base_Perfume  38028.739843
# 5                     110_film_Mixture  36357.288455
# 9                      111_gem_Mixture  34460.985092
# 21  114_oneout_default_pooling_Mixture  34110.996279
# 11                     111_gem_Perfume  33350.529224
# 19          113_oneout_roberta_Perfume  33171.308730
# 12                       111_gem_Smoke  29911.676264
# 17          113_oneout_roberta_Mixture  25965.914199
# 14               112_oneout_base_NoGas  23487.294092
# 25                diff_max_Mixture_MQ5  23068.292999
# 6                       110_film_NoGas  23005.980886
# 8                       110_film_Smoke  20978.635167
# 10                       111_gem_NoGas  15252.949252
# 23  114_oneout_default_pooling_Perfume  14726.146687
# 22    114_oneout_default_pooling_NoGas  13656.376471
# 20            113_oneout_roberta_Smoke  11285.308819
# 24    114_oneout_default_pooling_Smoke  10997.039487
# 18            113_oneout_roberta_NoGas  10167.136148
# 16               112_oneout_base_Smoke   9478.149632
# 0                                  MQ8   7034.436953
# 36                diff_min_Perfume_MQ8   5900.057937
# 26                diff_max_Mixture_MQ8   5195.396003
# 30                  diff_max_NoGas_MQ8   5121.555644
# 29                  diff_max_NoGas_MQ5   4895.412216
# 34                diff_max_Perfume_MQ8   4809.758885
# 28                diff_min_Mixture_MQ8   4606.951151
# 32                  diff_min_NoGas_MQ8   3878.058196
# /tmp/ipykernel_953284/534128026.py:184: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.89983120e-05 4.99830235e-01 4.99917191e-01 ... 5.66265985e-05
#  3.40830102e-05 2.36196446e-05]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   oof_df_train.loc[valid_index, col] += preds[:, j] / len(fold_list)
# /tmp/ipykernel_953284/534128026.py:184: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.99818418e-01 7.55343487e-05 2.86104021e-05 ... 4.99727172e-01
#  1.05539747e-04 3.49481434e-05]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   oof_df_train.loc[valid_index, col] += preds[:, j] / len(fold_list)
# /tmp/ipykernel_953284/534128026.py:184: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[8.36941887e-05 7.17815085e-05 2.70623102e-05 ... 1.48250853e-04
#  6.23879249e-05 4.53357238e-05]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   oof_df_train.loc[valid_index, col] += preds[:, j] / len(fold_list)
# /tmp/ipykernel_953284/534128026.py:184: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.88899443e-05 2.24491501e-05 2.71362070e-05 ... 6.79501223e-05
#  4.99797989e-01 4.99896096e-01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   oof_df_train.loc[valid_index, col] += preds[:, j] / len(fold_list)
# 0      NoGas
# 1    Perfume
# 2    Perfume
# 3    Mixture
# 4    Perfume
# Name: Gas, dtype: object
# A
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's multi_logloss: 0.288184
# [200]	valid_0's multi_logloss: 0.0929567
# [300]	valid_0's multi_logloss: 0.048618
# [400]	valid_0's multi_logloss: 0.0380947
# [500]	valid_0's multi_logloss: 0.0360313
# [600]	valid_0's multi_logloss: 0.0364763
# [700]	valid_0's multi_logloss: 0.0383198
# Early stopping, best iteration is:
# [511]	valid_0's multi_logloss: 0.0358981
# 0      NoGas
# 2    Perfume
# 3    Mixture
# 4    Perfume
# 5    Mixture
# Name: Gas, dtype: object
# A
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's multi_logloss: 0.286681
# [200]	valid_0's multi_logloss: 0.0907271
# [300]	valid_0's multi_logloss: 0.0455414
# [400]	valid_0's multi_logloss: 0.0341186
# [500]	valid_0's multi_logloss: 0.0308509
# [600]	valid_0's multi_logloss: 0.0301295
# [700]	valid_0's multi_logloss: 0.0304396
# Early stopping, best iteration is:
# [583]	valid_0's multi_logloss: 0.0300767
# 0      NoGas
# 1    Perfume
# 2    Perfume
# 4    Perfume
# 5    Mixture
# Name: Gas, dtype: object
# A
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's multi_logloss: 0.282591
# [200]	valid_0's multi_logloss: 0.0843304
# [300]	valid_0's multi_logloss: 0.0378653
# [400]	valid_0's multi_logloss: 0.0262258
# [500]	valid_0's multi_logloss: 0.0230891
# [600]	valid_0's multi_logloss: 0.022488
# [700]	valid_0's multi_logloss: 0.0225338
# [800]	valid_0's multi_logloss: 0.0234114
# Early stopping, best iteration is:
# [680]	valid_0's multi_logloss: 0.0224041
# 0      NoGas
# 1    Perfume
# 3    Mixture
# 5    Mixture
# 6    Mixture
# Name: Gas, dtype: object
# A
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's multi_logloss: 0.282697
# [200]	valid_0's multi_logloss: 0.0859953
# [300]	valid_0's multi_logloss: 0.0405176
# [400]	valid_0's multi_logloss: 0.0293922
# [500]	valid_0's multi_logloss: 0.0268911
# [600]	valid_0's multi_logloss: 0.0266121
# [700]	valid_0's multi_logloss: 0.027237
# Early stopping, best iteration is:
# [583]	valid_0's multi_logloss: 0.0265393
# 1    Perfume
# 2    Perfume
# 3    Mixture
# 4    Perfume
# 6    Mixture
# Name: Gas, dtype: object
# A
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's multi_logloss: 0.276042
# [200]	valid_0's multi_logloss: 0.082074
# [300]	valid_0's multi_logloss: 0.0384171
# [400]	valid_0's multi_logloss: 0.0276263
# [500]	valid_0's multi_logloss: 0.0252509
# [600]	valid_0's multi_logloss: 0.0248065
# [700]	valid_0's multi_logloss: 0.0248596
# Early stopping, best iteration is:
# [593]	valid_0's multi_logloss: 0.0247463
# Top 30 important features:
#                                Feature    Importance
# 13             112_oneout_base_Mixture  46015.759927
# 21  114_oneout_default_pooling_Mixture  43779.372657
# 15             112_oneout_base_Perfume  43608.736701
# 9                      111_gem_Mixture  41247.499048
# 11                     111_gem_Perfume  36746.849354
# 7                     110_film_Perfume  33938.155026
# 5                     110_film_Mixture  32200.638104
# 1                                  MQ5  31633.194594
# 19          113_oneout_roberta_Perfume  25579.857355
# 12                       111_gem_Smoke  23624.215510
# 23  114_oneout_default_pooling_Perfume  23176.134321
# 10                       111_gem_NoGas  21992.170715
# 17          113_oneout_roberta_Mixture  21928.710456
# 6                       110_film_NoGas  21760.776379
# 8                       110_film_Smoke  21034.380964
# 20            113_oneout_roberta_Smoke  17664.494398
# 25                diff_max_Mixture_MQ5  17425.040933
# 24    114_oneout_default_pooling_Smoke  16905.696835
# 22    114_oneout_default_pooling_NoGas  15136.128083
# 14               112_oneout_base_NoGas  14672.194730
# 16               112_oneout_base_Smoke  13814.916323
# 18            113_oneout_roberta_NoGas  10227.446097
# 32                  diff_min_NoGas_MQ8   7187.787561
# 26                diff_max_Mixture_MQ8   6302.633081
# 36                diff_min_Perfume_MQ8   5778.910201
# 27                diff_min_Mixture_MQ5   5490.281287
# 40                  diff_min_Smoke_MQ8   4743.963423
# 30                  diff_max_NoGas_MQ8   4729.394028
# 38                  diff_max_Smoke_MQ8   4583.950306
# 33                diff_max_Perfume_MQ5   4454.084179
# 0      NoGas
# 1    Perfume
# 2    Perfume
# 3    Mixture
# 4    Perfume
# Name: Gas, dtype: object
# A
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's multi_logloss: 0.285098
# [200]	valid_0's multi_logloss: 0.092531
# [300]	valid_0's multi_logloss: 0.048799
# [400]	valid_0's multi_logloss: 0.0382678
# [500]	valid_0's multi_logloss: 0.0365153
# [600]	valid_0's multi_logloss: 0.0371758
# [700]	valid_0's multi_logloss: 0.0388779
# Early stopping, best iteration is:
# [526]	valid_0's multi_logloss: 0.0364033
# 0      NoGas
# 2    Perfume
# 3    Mixture
# 4    Perfume
# 5    Mixture
# Name: Gas, dtype: object
# A
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's multi_logloss: 0.2827
# [200]	valid_0's multi_logloss: 0.0894236
# [300]	valid_0's multi_logloss: 0.0446568
# [400]	valid_0's multi_logloss: 0.0328469
# [500]	valid_0's multi_logloss: 0.0298408
# [600]	valid_0's multi_logloss: 0.0292503
# [700]	valid_0's multi_logloss: 0.0296353
# [800]	valid_0's multi_logloss: 0.0301847
# Early stopping, best iteration is:
# [600]	valid_0's multi_logloss: 0.0292503
# 0      NoGas
# 1    Perfume
# 2    Perfume
# 4    Perfume
# 5    Mixture
# Name: Gas, dtype: object
# A
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's multi_logloss: 0.280323
# [200]	valid_0's multi_logloss: 0.0842359
# [300]	valid_0's multi_logloss: 0.0386551
# [400]	valid_0's multi_logloss: 0.0268874
# [500]	valid_0's multi_logloss: 0.0237689
# [600]	valid_0's multi_logloss: 0.0229022
# [700]	valid_0's multi_logloss: 0.0232983
# [800]	valid_0's multi_logloss: 0.0239775
# Early stopping, best iteration is:
# [625]	valid_0's multi_logloss: 0.0228056
# 0      NoGas
# 1    Perfume
# 3    Mixture
# 5    Mixture
# 6    Mixture
# Name: Gas, dtype: object
# A
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's multi_logloss: 0.27974
# [200]	valid_0's multi_logloss: 0.0855324
# [300]	valid_0's multi_logloss: 0.0408176
# [400]	valid_0's multi_logloss: 0.0296873
# [500]	valid_0's multi_logloss: 0.0271567
# [600]	valid_0's multi_logloss: 0.0267441
# [700]	valid_0's multi_logloss: 0.0271683
# [800]	valid_0's multi_logloss: 0.0280721
# Early stopping, best iteration is:
# [610]	valid_0's multi_logloss: 0.0267024
#       Mixture     NoGas   Perfume     Smoke
# 0    0.000750  0.002717  0.002844  0.993689
# 1    0.000493  0.009146  0.989829  0.000532
# 2    0.000306  0.998038  0.001271  0.000386
# 3    0.000265  0.997806  0.001643  0.000286
# 4    0.999182  0.000372  0.000342  0.000105
# ..        ...       ...       ...       ...
# 635  0.000726  0.002631  0.002714  0.993928
# 636  0.000155  0.000442  0.999241  0.000162
# 637  0.000172  0.000606  0.999043  0.000178
# 638  0.000564  0.001936  0.002208  0.995292
# 639  0.000555  0.002408  0.002051  0.994986
#
# [640 rows x 4 columns]
#       MQ8  MQ5   min_temp   max_temp    dff_tmp  fold      Gas  \
# 0     632  418  28.000000  31.000000   3.000000     0    NoGas
# 1     567  392  30.000000  30.000000   0.000000     2  Perfume
# 2     562  393  31.111111  31.111111   0.000000     4  Perfume
# 3     352  441  21.666667  22.222222   0.555556     3  Mixture
# 4     603  412  17.000000  36.000000  19.000000     4  Perfume
# ...   ...  ...        ...        ...        ...   ...      ...
# 5755  557  331  31.666667  31.666667   0.000000     3    Smoke
# 5756  595  300  33.888889  33.888889   0.000000     1    Smoke
# 5757  571  397  38.000000  38.000000   0.000000     4  Perfume
# 5758  542  392  29.000000  30.000000   1.000000     2    NoGas
# 5759  623  322  40.000000  40.000000   0.000000     4    Smoke
#
#       110_film_Mixture  110_film_NoGas  110_film_Perfume  ...  \
# 0             0.000000        0.964642          0.010194  ...
# 1             0.000000        0.105679          0.863205  ...
# 2             0.032340        0.243037          0.687438  ...
# 3             0.957907        0.014041          0.013309  ...
# 4             0.000000        0.016182          0.956950  ...
# ...                ...             ...               ...  ...
# 5755          0.014811        0.012661          0.020056  ...
# 5756          0.012677        0.011375          0.015636  ...
# 5757          0.000000        0.013266          0.951928  ...
# 5758          0.000000        0.963755          0.006039  ...
# 5759          0.015193        0.014813          0.013380  ...
#
#       113_oneout_roberta_Smoke  114_oneout_default_pooling_Mixture  \
# 0                     0.000000                            0.000000
# 1                     0.000000                            0.000000
# 2                     0.043392                            0.114975
# 3                     0.053555                            2.941895
# 4                     0.000000                            0.000000
# ...                        ...                                 ...
# 5755                  0.929443                            0.075470
# 5756                  0.949219                            0.105637
# 5757                  0.000000                            0.000000
# 5758                  0.000000                            0.000000
# 5759                  0.947998                            0.055081
#
#       114_oneout_default_pooling_NoGas  114_oneout_default_pooling_Perfume  \
# 0                             2.938232                            0.075432
# 1                             0.626892                            1.818848
# 2                             0.270081                            1.781982
# 3                             0.067022                            0.077293
# 4                             0.129822                            2.956299
# ...                                ...                                 ...
# 5755                          0.073061                            0.097023
# 5756                          0.065237                            0.060602
# 5757                          0.146729                            2.967529
# 5758                          2.923096                            0.052641
# 5759                          0.051631                            0.076027
#
#       114_oneout_default_pooling_Smoke  another_fold   Mixture     NoGas  \
# 0                             0.000000             0  0.000100  0.999629
# 1                             0.000000             2  0.000907  0.032919
# 2                             0.046670             4  0.001842  0.294692
# 3                             0.070049             3  0.999909  0.000034
# 4                             0.000000             4  0.000770  0.021384
# ...                                ...           ...       ...       ...
# 5755                          2.916260             3  0.000028  0.000074
# 5756                          2.922363             1  0.000149  0.000189
# 5757                          0.000000             4  0.000117  0.000510
# 5758                          0.000000             2  0.000167  0.998929
# 5759                          2.918457             4  0.000049  0.000074
#
#        Perfume     Smoke
# 0     0.000171  0.000100
# 1     0.964454  0.001720
# 2     0.699712  0.003753
# 3     0.000036  0.000022
# 4     0.977077  0.000769
# ...        ...       ...
# 5755  0.000060  0.999838
# 5756  0.000164  0.999498
# 5757  0.999226  0.000146
# 5758  0.000700  0.000204
# 5759  0.000063  0.999814
#
# [5760 rows x 32 columns]
# OOF F1スコア: 0.9908050526047958

# %%
oof_df_train.to_csv(f"../outputs/stacking_{out_str}_oof.csv", index=False)
sub.to_csv(f"../outputs/stacking_{out_str}_submission.csv", index=False)
